# %%
print("Hello,Data Science")
# Out:
# Hello,Data Science

# %%
name = "Aditya"
age = 20
cgpa = 8.5
is_student = True
print(name,age,cgpa,is_student)
# Out:
# Aditya 20 8.5 True

# %%
name = input("Enter your name")
branch = input("Enter your branch")

print("Hello", name)
print("You are studying in ",branch)
# Out:
# Enter your name Aditya Singh Rathore
# Enter your branch CSE-IOt
# Hello Aditya Singh Rathore
# You are studying in  CSE-IOt

# %%
name = input("Enter your name")
age = input("Enter your age")
college_name = input("Enter your college name")
current_year = input("Enter your current year")

print("Name: ",name)
print("Age: ",age)
print("College Name: ",college_name)
print("Current Year: ",current_year)
# Out:
# Enter your name Aditya Singh Rathore
# Enter your age 20
# Enter your college name LNCT
# Enter your current year 3rd
# Name:  Aditya Singh Rathore
# Age:  20
# College Name:  LNCT
# Current Year:  3rd
